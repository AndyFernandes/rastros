# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("social/populacao/populacao.csv",sep=",")
data = data.replace(np.nan, 0)

# %%
data
# Out:
#       Código           Espacialidades  População total 1991  \
# 0         76                   Brasil             146825475
# 1    2300101                  Abaiara                  7889
# 2    2300150                  Acarape                 11173
# 3    2300200                   Acaraú                 45505
# 4    2300309                 Acopiara                 49259
# 5    2300408                   Aiuaba                 13219
# 6    2300507               Alcântaras                  8606
# 7    2300606                Altaneira                  4806
# 8    2300705               Alto Santo                 13043
# 9    2300754                 Amontada                 25161
# 10   2300804        Antonina do Norte                  5086
# 11   2300903                 Apuiarés                  9516
# 12   2301000                  Aquiraz                 46305
# 13   2301109                  Aracati                 50495
# 14   2301208                Aracoiaba                 22508
# ...

# %%
data1991 = data.loc[:,["Código","Espacialidades","População total 1991"]]
data2000 = data.loc[:,["Código","Espacialidades","População total 2000"]]
data2010 = data.loc[:,["Código","Espacialidades","População total 2010"]]

data1991.to_csv("populacao_1991.csv", sep=",", index=False)
data2000.to_csv("populacao_2000.csv", sep=",", index=False)
data2010.to_csv("populacao_2010.csv", sep=",", index=False)

# %%
data = pd.read_csv("social/idh/idh.csv",sep=",")
data = data.replace(np.nan, 0)
data.head()
# Out:
#         id Nome Localidade   1991   2000   2010  Unidade  Multiplicador
# 0  2300101  IDH    Abaiara  0.286  0.452  0.628      0.0            0.0
# 1  2300150  IDH    Acarape  0.349  0.490  0.606      0.0            0.0
# 2  2300200  IDH     Acaraú  0.277  0.415  0.601      0.0            0.0
# 3  2300309  IDH   Acopiara  0.254  0.412  0.595      0.0            0.0
# 4  2300408  IDH     Aiuaba  0.256  0.365  0.569      0.0            0.0

# %%
data1991 = data.loc[:,["id","Localidade","1991"]]
data2000 = data.loc[:,["id","Localidade","2000"]]
data2010 = data.loc[:,["id","Localidade","2010"]]

data1991.to_csv("social/idh/idh_1991.csv", sep=",", index=False)
data2000.to_csv("social/idh/idh_2000.csv", sep=",", index=False)
data2010.to_csv("social/idh/idh_2010.csv", sep=",", index=False)

# %%
pib = pd.read_csv("social/pib/pib.csv",sep=",")
pib = pib.replace(np.nan, 0)
pib["id"] = data["id"]
pib.head()
# Out:
#    Posição             Nome Localidade   1999   2000   2001    2002    2003  \
# 0      1.3  Série encerrada    Abaiara  10025  11327  11551   12418   15396
# 1      1.3  Série encerrada    Acarape  26418  29110  29895   30580   31731
# 2      1.3  Série encerrada     Acaraú  70664  68209  83643  100703  116638
# 3      1.3  Série encerrada   Acopiara  62878  71419  64515   78579   87137
# 4      1.3  Série encerrada     Aiuaba  16737  16242  15550   18725   24235
#
#      2004    2005   ...       2010    2011    2012  2013  2014  2015  2016  \
# 0   16213   16519   ...      35616   40098   39314   0.0   0.0   0.0   0.0
# 1   33141   32591   ...      57412   81090   80588   0.0   0.0   0.0   0.0
# 2  134321  141564   ...     327218  376651  394094   0.0   0.0   0.0   0.0
# 3  101079  105507   ...     202778  236257  236047   0.0   0.0   0.0   0.0
# 4   24448   29668   ...      53768   66998   61575   0.0   0.0   0.0   0.0
#
#    Unidade  Multiplicador       id
# ...

# %%
pib1999 = pib.loc[:,["id","Localidade","1999"]]
pib2000 = pib.loc[:,["id","Localidade","2000"]]
pib2001 = pib.loc[:,["id","Localidade","2001"]]
pib2002 = pib.loc[:,["id","Localidade","2002"]]
pib2003 = pib.loc[:,["id","Localidade","2003"]]
pib2004 = pib.loc[:,["id","Localidade","2004"]]
pib2005 = pib.loc[:,["id","Localidade","2005"]]
pib2006 = pib.loc[:,["id","Localidade","2006"]]
pib2007 = pib.loc[:,["id","Localidade","2007"]]
pib2008 = pib.loc[:,["id","Localidade","2008"]]
pib2009 = pib.loc[:,["id","Localidade","2009"]]
pib2010 = pib.loc[:,["id","Localidade","2010"]]
pib2011 = pib.loc[:,["id","Localidade","2011"]]
pib2012 = pib.loc[:,["id","Localidade","2012"]]
pib2013 = pib.loc[:,["id","Localidade","2013"]]
pib2014 = pib.loc[:,["id","Localidade","2014"]]
pib2015 = pib.loc[:,["id","Localidade","2015"]]
pib2016 = pib.loc[:,["id","Localidade","2016"]]

pib1999.to_csv("social/pib/pib_1999.csv", sep=",", index=False)
pib2000.to_csv("social/pib/pib_2000.csv", sep=",", index=False)
pib2001.to_csv("social/pib/pib_2001.csv", sep=",", index=False)
pib2002.to_csv("social/pib/pib_2002.csv", sep=",", index=False)
pib2003.to_csv("social/pib/pib_2003.csv", sep=",", index=False)
pib2004.to_csv("social/pib/pib_2004.csv", sep=",", index=False)
pib2005.to_csv("social/pib/pib_2005.csv", sep=",", index=False)
pib2006.to_csv("social/pib/pib_2006.csv", sep=",", index=False)
pib2007.to_csv("social/pib/pib_2007.csv", sep=",", index=False)
pib2008.to_csv("social/pib/pib_2008.csv", sep=",", index=False)
pib2009.to_csv("social/pib/pib_2009.csv", sep=",", index=False)
pib2010.to_csv("social/pib/pib_2010.csv", sep=",", index=False)
pib2011.to_csv("social/pib/pib_2011.csv", sep=",", index=False)
pib2012.to_csv("social/pib/pib_2012.csv", sep=",", index=False)
pib2013.to_csv("social/pib/pib_2013.csv", sep=",", index=False)
pib2014.to_csv("social/pib/pib_2014.csv", sep=",", index=False)
pib2015.to_csv("social/pib/pib_2015.csv", sep=",", index=False)
pib2016.to_csv("social/pib/pib_2016.csv", sep=",", index=False)
